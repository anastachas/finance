# %%
import pandas as pd

# %%
starling_df = pd.read_excel('/Users/anast/Desktop/Statements/Starling.xlsx', sheet_name=None)

# %%
starling_df = pd.read_excel(
    r"C:\Users\anast\Desktop\Statements\Starling.xlsx",
    sheet_name=None
)

# %%
display(starling_df)
# Out:
# {'2024':           Date                   Counter Party         Reference  \
#  0   2024-05-17                Sophia Anastacha               NaN
#  1   2024-05-17                Sophia Anastacha  Sophia Anastacha
#  2   2024-05-25                     S Anastacha  Monthly spending
#  3   2024-05-26                    Tesco Petrol    TESCO PFS 3741
#  4   2024-05-26                             B&Q        B & Q 1216
#  ..         ...                             ...               ...
#  178 2024-12-26         Sophia Anastacha Lloyds       credit card
#  179 2024-12-26                     S Anastacha          TRANSFER
#  180 2024-12-26  Sophia Anastacha & Guy Johnson      pets at home
#  181 2024-12-26         Sophia Anastacha Lloyds       credit card
#  182 2024-12-26                     S Anastacha          TRANSFER
#
#                 Type  Amount (GBP)  Balance (GBP) Spending Category  Notes
#  0    FASTER PAYMENT        162.00         162.00            INCOME    NaN
# ...

# %%
starling_df = pd.concat(starling_df.values(), ignore_index=True)

# %%
display(starling_df)
# Out:
#           Date            Counter Party               Reference  \
# 0   2024-05-17         Sophia Anastacha                     NaN
# 1   2024-05-17         Sophia Anastacha        Sophia Anastacha
# 2   2024-05-25              S Anastacha        Monthly spending
# 3   2024-05-26             Tesco Petrol          TESCO PFS 3741
# 4   2024-05-26                      B&Q              B & Q 1216
# ..         ...                      ...                     ...
# 444 2026-03-29       Jack's Gelato - Al  SQ *JACK'S GELATO - AL
# 445 2026-03-29      Byron Covent Garden         BYRON CAMBRIDGE
# 446 2026-03-29    John Lewis & Partners       JOHN LEWIS STORES
# 447 2026-03-29  Sophia Anastacha Lloyds                  pecoro
# 448 2026-03-30                 MiPermit            OBN*MiPermit
#
#                   Type  Amount (GBP)  Balance (GBP) Spending Category  Notes
# 0       FASTER PAYMENT        162.00         162.00            INCOME    NaN
# ...

# %%
 starling_df.insert(1, 'Account', 'Starling')

# %%
display(starling_df)
# Out:
#           Date   Account            Counter Party               Reference  \
# 0   2024-05-17  Starling         Sophia Anastacha                     NaN
# 1   2024-05-17  Starling         Sophia Anastacha        Sophia Anastacha
# 2   2024-05-25  Starling              S Anastacha        Monthly spending
# 3   2024-05-26  Starling             Tesco Petrol          TESCO PFS 3741
# 4   2024-05-26  Starling                      B&Q              B & Q 1216
# ..         ...       ...                      ...                     ...
# 444 2026-03-29  Starling       Jack's Gelato - Al  SQ *JACK'S GELATO - AL
# 445 2026-03-29  Starling      Byron Covent Garden         BYRON CAMBRIDGE
# 446 2026-03-29  Starling    John Lewis & Partners       JOHN LEWIS STORES
# 447 2026-03-29  Starling  Sophia Anastacha Lloyds                  pecoro
# 448 2026-03-30  Starling                 MiPermit            OBN*MiPermit
#
#                   Type  Amount (GBP)  Balance (GBP) Spending Category  Notes
# ...
